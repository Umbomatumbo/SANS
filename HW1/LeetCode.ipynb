# %%
class Solution(object):
    def isValid(self, s):
        """
        :type s: str
        :rtype: bool
        """
        stack =[]
        for char in s:
            print(char, "is the char------------------")
            pop = ""
            if self.isOpen(char):
                print(char, "is open")
                stack.append(char)
                print(char)
            else:
                print(char, "is not open")
                try:

                    pop = stack.pop()
                    print(pop)
                except:
                    return False
                print("checking if ", char, "is same type as ", pop, "------------------")
                if not self.sameType(char,pop):
                    print ("not same type")
                    return False
                else:
                    print("same type")

            
        if len(stack)==0 :
            return True
        else :
            return False
        
    def sameType(self,char1,char2):
        if self.typeC(char1) == self.typeC(char2) :
            return True
        return False
    
    def typeC(self,char):
        if char == "(" or char == ")":
            return 0
        if char == "(" or char == ")":
            return 1
        if char == "(" or char == ")":
            return 2
        else:
            return -1       
        
    def isOpen(self,char):
        if char == "(" or char == "[" or char == "{":
            return True
        else:
            return False

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        head = ListNode()
        node = head
        while list1!=None and list2!=None:
            if list1.val > list2.val :
                node.next = list2
                list2 = list2.next
            else :
                node.next = list1
                list1 = list1.next
        
        while list1!=None:
            node.next = list1
            list1 = list1.next
        
        while list2!=None :
            node.next = list2
            list1 = list2.next
        
        return head

# %%
s = ''.join(c for c in s.lower() if c.isalnum())

        stack = []
        for i in range(len(s)//2):
            stack.append(s[i]) 

        for i in range(len(s)//2,len(s)) :
            if not  stack.pop == s[i]:
                return False
        
        return True
# Out:
#   Cell In[27], line 3
#     stack = []
#     ^
# IndentationError: unexpected indent

# %%
s = ''.join(c for c in s.lower() if c.isalnum())
stack = []
if len(s)==0:
    print(False) 

if len(s)%2:    
    for i in range(len(s)//2+1):
        stack.append(s[i]) 

    for i in range(len(s)//2,len(s)) :
        if not  stack.pop() == s[i]:
            print(False)
else:
    for i in range(len(s)//2):
        stack.append(s[i]) 

    for i in range(len(s)//2,len(s)) :
        if not  stack.pop == s[i]:
            print(False)
